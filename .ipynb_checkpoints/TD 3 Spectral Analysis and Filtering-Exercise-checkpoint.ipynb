# %%
from __future__ import division
import numpy as np
import scipy.fftpack as sf
import matplotlib.pyplot as plt
import pylab as pl
import scipy.signal as sig
from scipy import misc

# %% [markdown]
# ## 1. STFT  (Short Time Fourier Transform) and source separation.

# %% [markdown]
# ## In this part, we use STFT which is a collection of Fourier transform of a 1D signal on time subintervals. Why using STFT ?
# - The length of a music signal for 4 minutes sampled at a rate of 44kHz is roughly $2500*44000 \simeq 1.1 \times 10^7$.
# - The length of a music note is of the order of a second.
# ### Conclusion: do not use FFT on the whole signal but on short segments of it.
#
# ### We use it in order to experiment source separation which comes from the idea that the different signals may present very different behaviour in the frequency domain.

# %%
# utils to load the sounds.
import numpy as np
import wave as wv

def load_sound(file, n0):
    
    x_raw = wv.open(file)
    n = x_raw.getnframes()
    x = np.frombuffer(x_raw.readframes(-1), 'Int16')
    x_raw.close()
    
    if file[::-1][:8][::-1] == "bird.wav":
        x = np.delete(x,list(range(6001)) + list(range(12500, 15001)) + list(range(22500, 24001)) + list(range(32500,34001)))

    if n0 !=0 and n0 < n:
        x = x[:n0]
    
    return x/np.max(x)

# %% [markdown]
# ## Hereafter, we load the $3$ sounds and plot the second one.

# %%
n = 1024*16
s = 3 #number of signals.
x = np.zeros([n,3])
x[:,0] = load_sound("bird.wav",n)
x[:,1] = load_sound("female.wav",n)
x[:,2] = load_sound("male.wav",n)

## listen to a sound.
from IPython.display import Audio
Audio(x[:,2], rate = 15000)
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:9: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Show the numerical signal.
x = x/np.tile(np.std(x,0),(n,1))
p = 2 #number of micros
import matplotlib.pyplot as plt
plt.figure(figsize = (15,15))
plt.xlim(0,n)
plt.plot(x[:,2])
plt.show()

# %% [markdown]
# ### We simulate two micros which are implemented by linear combinations of the signals.

# %%
theta = np.linspace(0, np.pi, s + 1)[:-1]
theta[0] = .2
M = np.vstack((np.cos(theta), np.sin(theta)))

## recorded signals
y = np.dot(x,np.transpose(M))
print("length of the signals",np.shape(y))

# Listen to the two recorded signals.
from IPython.display import Audio
Audio(y[:,1], rate = 15000)
# Out:
# length of the signals (16384, 2)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### We use the STFT function from the python package signal and plot it.

# %%
import scipy.signal as sig

f,t,w = sig.stft(x[:,0])
a,b,z = sig.stft(x[:,1])

print(np.size(z))

plt.figure(figsize = (10,10))

plt.subplot(1,2,1)
plt.title("stft of signal 1")
plt.imshow(np.log(np.abs(w)))

plt.subplot(1,2,2)
plt.title("stft of signal 2")
plt.imshow(np.log(np.abs(z)))

plt.show()
# Out:
# 16641

# %% [markdown]
# ### We numerically check that the STFT and ISTFT are indeed inverse from each others.

# %%
micro1 = y[:,0]
micro2 = y[:,1]

stft = lambda im : sig.stft(im,noverlap = 64,nperseg = 128)
istft = lambda im : sig.istft(im,noverlap = 64,nperseg = 128)

f,t,w1 = stft(micro1)
print(np.shape(w1))

f,t,w2 = stft(micro2)
W = np.asarray([w1.flatten(),w2.flatten()])
print(np.shape(W))

t,recov = istft(w1)
print(np.sum((micro1 - recov)**2))
# Out:
# (65, 257)
# (2, 16705)
# 1.023395155796052e-27

# %% [markdown]
# ### By selecting randomly a group of points in time, we plot in the plane the coordinates of the points, being the measured signals by the micros.

# %%
nbre_selec = 2000

from random import shuffle

print(np.shape(y)[0])

liste = [ i for i in range(np.shape(y)[0])]

shuffle(liste)
plt.plot(y[liste[0:nbre_selec],0], y[liste[0:nbre_selec],1], "o", markersize=1)
plt.show()
# Out:
# 16384

# %% [markdown]
# ### Q: Do the same with the STFT signals, what do you observe ?

# %%
### your code here.
used_signal = W
used_signal = used_signal.transpose()
stft_list = [ i for i in range(np.shape(used_signal)[0])]
shuffle(stft_list)

plt.plot(used_signal[stft_list[0:nbre_selec],0], used_signal[stft_list[0:nbre_selec],1], "o", markersize=1)
plt.show()


"""
On observe que les points ont l'air de se rapprocher de 3 droites passant par l'origine.
"""
# Out:
# /home/6im3/mpluchar/.local/lib/python3.5/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# "\nOn observe que les points ont l'air de se rapprocher de 3 droites passant par l'origine.\n"

# %% [markdown]
# ### Q: For each point in the plot above, compute its angle and plot the distribution of the angles (use the function np.histogram) and plot it.

# %%
import math

selected_points = used_signal[stft_list[0:nbre_selec],0], used_signal[stft_list[0:nbre_selec],1]
signal_angles = []

for i in stft_list:
    angle = math.atan2(used_signal[i, 0].real, used_signal[i, 1].real)
    angle = angle % np.pi
    signal_angles.append(angle)

    
plt.figure(figsize=(20,10))
plt.title("Distribution")
histogram = plt.hist(signal_angles, bins=200)
plt.show()

# %% [markdown]
# ### Q: By selecting the highest peaks of the distribution, estimate the angles of the mixing.

# %%
## insert your code here.
peak_counts, peak_bins = np.histogram(signal_angles, bins=200)
peaks, properties = sig.find_peaks(peak_counts)
print(peaks)
plt.hist(signal_angles, bins=nbre_selec)
plt.plot(peak_bins[peaks], peak_counts[peaks])
plt.show()

sub_signal = peak_counts[peaks]
sub_peaks, properties = sig.find_peaks(peak_counts[peaks], threshold=50)
print(sub_peaks)
print(peaks[sub_peaks])
plt.show()

directions = peak_bins[peaks[sub_peaks]]
print("\nAngle peaks are ")
print(directions)
# Out:
# [  4   6   8  13  16  20  25  30  33  41  45  48  50  53  58  61  66  69
#   71  87  93  95 100 104 112 115 117 119 123 126 129 132 134 138 142 145
#  149 153 157 161 166 172 177 181 185 188 190 192 195 198]
# [ 8 19 40]
# [ 33  87 166]
#
# Angle peaks are
# [0.51827047 1.36632741 2.60700331]

# %% [markdown]
# ### Q: Using the STFT recorded signals, take each point in the plane and compute its projection on each recovered directions. It gives a vector of 3 estimated projections.

# %%
## insert your code here.

from numpy import * 

# https://stackoverflow.com/questions/49061521/projection-of-a-point-to-a-line-segment-python-shapely
plt.figure(figsize=(20, 20))
lines = []
dots = []
for a in directions:
    print("angle is " + str(a))
    x = math.cos(a)
    y = math.sin(a)
    print([x,y])
    plt.plot([x, 0], [y, 0], color='r', linestyle='-', linewidth=0.5)
    direction = [x, y]    
    dot_AB_AB = np.dot(direction, direction)
    lines.append(direction)
    dots.append(dot_AB_AB)

projections = [[] for i in range(3)]
for pt in used_signal[:nbre_selec]:
    plt.plot(pt[0], pt[1], "og", markersize=0.5)
    #print(pt)
    for i in range(len(lines)):
        direction = lines[i]
        
        # Projection
        # Project P on line l is :
        # (l ° P) l
        A = [0,0]
        B = direction
        P = pt        
        dot_AP_AB = np.dot(pt, direction)
        dot_AB_AB = dots[i]
        multiplier = dot_AP_AB / dot_AB_AB
        projection = [ x * multiplier for x in direction ]
        projection.append(multiplier)
        projections[i].append(projection)
        # projection = A + dot(AP,AB) / dot(AB,AB) * AB
        plt.plot(projection[0], projection[1], "ob", markersize=2)
        #print("projection is " + str(projection))

plt.title("directions")
plt.show()
# Out:
# angle is 0.5182704683495788
# [0.8686772512294433, 0.4953784747003635]
# angle is 1.366327412224945
# [0.2030471661969792, 0.9791689579941637]
# angle is 2.6070033115981657
# [-0.8604779270368595, 0.5094877202468662]
# /home/6im3/mpluchar/.local/lib/python3.5/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Q: For each frequency point in the signal STFT, select the direction on which it has the largest projection. And threshold using the code below.

# %%
threshold = .005
#D = np.sqrt(np.sum(W**2, 0))
#I = I*(D > threshold)

projected_signal = []

for i in range(nbre_selec):
#for i in range(3):
    pt = used_signal[i]
    
    largest_projection = None
    largest_projection_multiplier = 0
    
    # Find the largest projection
    for j in range(3) :
        p_multiplier = np.abs(projections[j][i][2])
        p_projection = projections[j][i][:2]
        #print(p_projection)
        if p_multiplier > largest_projection_multiplier:
            largest_projection_multiplier = p_multiplier
            largest_projection = p_projection
            
    if p_multiplier > threshold:
        plt.plot(largest_projection[0], largest_projection[1], "og", markersize=3)
        projected_signal.append(largest_projection)

plt.title("points")
plt.show()
# Out:
# /home/6im3/mpluchar/.local/lib/python3.5/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (1805, 2)
# [ 0.29731969 -0.05508423 -0.31070334 -0.17376545 -0.39244731 -0.08160264
#   0.45658917  0.23804113  0.03246338  0.16259583 -0.13486257 -0.04054382
#  -0.04435317 -0.06489367 -0.05976163 -0.00290347 -0.33200251 -0.29390048
#   0.2921311   0.44547423 -0.00833544 -0.02976762 -0.07372521 -0.27364507
#  -0.07652862  0.20300477 -0.22077599 -0.3606252   0.25255942 -0.05939457
#   0.31309215  0.14543707  0.37809161  0.02083712 -0.00502684 -0.31146857
#  -0.47243679  0.07617518  0.53920133  0.23332696 -0.00327939 -0.70357662
#  -0.241038    0.32015327 -0.01136858  0.12154206  0.06358778 -0.10954527
#  -0.25650613  0.09253094  0.1477429   0.33370345  0.40361236  0.2078344
#  -0.79993416 -0.74919382  0.15988946  0.77187756  0.11283466  0.07013542
#  -0.08511858 -0.19079106  0.03147205 -0.0659045 ]
# (64,)

# %% [markdown]
# ### Q: Plot the STFT and the time domain of the recovered signals and the original signals. Estimate the performance using the SNR implemented below.

# %%
def snr(x, y):
    s =  np.linalg.norm(x - y)
    if s == 0:
        return "Equal inputs"
    return 20 * np.log10(np.linalg.norm(x) /s)









t, recov = istft(projected_signal)
print(np.shape(projected_signal))
print(recov)
print(np.shape(recov))
print(w)

# plot
plt.figure(figsize = (10,10))

plt.subplot(1,2,1)
plt.title("recovered signal")
plt.imshow(np.log(np.abs(projected_signal)))

plt.subplot(1,2,1)
plt.title("original signal")
plt.imshow(np.log(np.abs(w)))

plt.show()
# Out:
# (1805, 2)
# [ 0.29731969 -0.05508423 -0.31070334 -0.17376545 -0.39244731 -0.08160264
#   0.45658917  0.23804113  0.03246338  0.16259583 -0.13486257 -0.04054382
#  -0.04435317 -0.06489367 -0.05976163 -0.00290347 -0.33200251 -0.29390048
#   0.2921311   0.44547423 -0.00833544 -0.02976762 -0.07372521 -0.27364507
#  -0.07652862  0.20300477 -0.22077599 -0.3606252   0.25255942 -0.05939457
#   0.31309215  0.14543707  0.37809161  0.02083712 -0.00502684 -0.31146857
#  -0.47243679  0.07617518  0.53920133  0.23332696 -0.00327939 -0.70357662
#  -0.241038    0.32015327 -0.01136858  0.12154206  0.06358778 -0.10954527
#  -0.25650613  0.09253094  0.1477429   0.33370345  0.40361236  0.2078344
#  -0.79993416 -0.74919382  0.15988946  0.77187756  0.11283466  0.07013542
#  -0.08511858 -0.19079106  0.03147205 -0.0659045 ]
# (64,)
# [[ 1.07549512e-02+0.00000000e+00j  1.85106016e-02+0.00000000e+00j
#    1.82068010e-02+0.00000000e+00j ...  2.12298212e-02+0.00000000e+00j
#    1.62141666e-02+0.00000000e+00j -1.98761143e-03+0.00000000e+00j]
#  [-5.86229849e-03+6.77124335e-03j -9.74115279e-03-2.88106952e-04j
#   -9.35175981e-03+2.05969762e-03j ... -1.26242819e-02+1.40778423e-04j
#   -7.97919650e-03+5.29055183e-05j  6.08972308e-03-5.19489653e-03j]
#  [ 2.18094707e-04-5.32086449e-03j  9.84587421e-04-1.09158277e-03j
#    1.14657338e-03-2.42997968e-03j ...  2.97245229e-03-8.07668074e-04j
#    7.33945930e-04+2.52671274e-04j -1.03679675e-02+3.11099164e-03j]
#  ...
#  [ 1.62707688e-04-3.74918087e-05j -4.42353220e-05+1.29060756e-05j
#    1.63643973e-05-2.66422080e-05j ... -2.53761592e-04+1.54588725e-04j
#   -2.85556526e-04+2.97402472e-04j  4.26578200e-03+1.05718709e-04j]
#  [-1.85846563e-04+2.33958581e-05j  2.42338483e-04+4.05933691e-05j
#   -5.67573254e-05-3.04290340e-05j ...  1.23269263e-04-2.35400087e-04j
#   -1.10941793e-04-1.84152531e-04j -4.26915968e-03+9.51007603e-05j]
#  [ 1.75105696e-04+0.00000000e+00j -3.02928502e-04+0.00000000e+00j
#    7.82916152e-06+0.00000000e+00j ... -3.27170739e-05+0.00000000e+00j
#    4.20367865e-04+0.00000000e+00j  4.44459178e-03+0.00000000e+00j]]

# %% [markdown]
# ### Q: Listen to the reconstructed signals and the original signals.

# %%
i = 0
from IPython.display import Audio
Audio(recov, rate = 15000)
# Out:
#                 <audio controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
Audio(x[:, i], rate = 15000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 2. The goal of this part is to explore implementations of a FIR or an IIR.

# %% [markdown]
# ## We plot below a signal with a mix of low and high frequencies.

# %%
f = lambda t: np.cos(np.pi*t) + 0.2*np.sin(5*np.pi*t+0.1) + 0.2*np.sin(30*np.pi*t)  + 0.1*np.sin(32*np.pi*t+0.1) + 0.1*np.sin(47* np.pi*t+0.8)
t=np.linspace(-10,10,1000); signal=f(t)
print(np.shape(t),np.shape(signal))
plt.plot(t, signal)
# Out:
# (1000,) (1000,)

# %% [markdown]
# ## Q1. Implement an ideal low pass filter using Fourier transform in 1D:
# ### Compute the inverse FFT of a low pass filter and cut it with a window that will be passed in argument and apply it to the signal above by convolution or using FFT.

# %% [markdown]
# ## Q2. Using the code below, implement an IIR filter defined by its numerator which will be set to a  constant $b$ and its denominator which will be set to $1-az^{-1}$.
# ### What can you say about the range of the parameter $a$ in order to obtain a stable filter.
# ### Experimentally, determine the ranges of $a$ to get respectively a low-pass filter and a high-pass filter. Give a theoretical explanation.

# %%
def myIIR(x,a,b):
    ### a is the numerator
    ### b is the denominator
    assert(len(a)==len(b)),"a,b must have the same length"
    y = np.zeros_like(x)
    k = len(a)
    for i in range(len(a),len(x)):
        y[i] = np.sum(np.flipud(b)*y[i-k:i]) + np.sum(np.flipud(a) * x[i-k+1:i+1])
    return y

# %% [markdown]
# ## In the following, we are given an electrocardiogram. We plot it as a function of time.

# %%
### load the data which is an electrocardiogram which is sampled at 360Hz
ecg = misc.electrocardiogram()
### Different plots.
fs = 360.0
### Since it is sampled at 360Hz, recall that Hz is the number of cycle per second, then the
### time is obtained as follows:
time = np.arange(ecg.size) / fs
### simple plot.
plt.plot(time, ecg)
plt.xlabel("time in s")
plt.ylabel("ECG in mV")
plt.xlim(9, 10.2)
plt.ylim(-1, 1.5)
plt.show()
print("time min", time[0])
print("time max", time[-1])
# Out:
# time min 0.0
# time max 299.9972222222222

# %%
### Use the scipy function to get the power spectrum of the signal.
f, Pxx = sig.welch(ecg, fs=fs, nperseg=2048, scaling="spectrum")
plt.semilogy(f, Pxx)
plt.xlabel("Frequency in Hz")
plt.ylabel("Power spectrum of the ECG in mV**2")
plt.xlim(f[[0, -1]])
plt.show()

# %% [markdown]
# ## Q3. Estimate the number of heartbeats in the following electrocardiogram and estimate the mean value of the interval between two heartbeats. You can use the method of your choice. A possible method consists in using a band pass filter and then extract the maximum values of the filtered signal.
